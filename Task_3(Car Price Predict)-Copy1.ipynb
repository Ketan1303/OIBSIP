# %%
# Import Libraries
import pandas as pd
import numpy as np
import  matplotlib.pyplot as plt

# %%
# Importing datasets
db = pd.read_csv("A:\CarPrice_Assignment.csv")
db
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %% [markdown]
# # Data Analysis

# %%
db.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
# Checking the NULL values
db.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
print(db.shape)
# Out:
# (205, 26)

# %%
print(db.columns)
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %% [markdown]
# # Data Visualisation

# %%
# Removing unnecessary columns for better accuracy
db = db.drop(columns =["car_ID","CarName","fueltype","enginelocation", "wheelbase","carlength", "carwidth", "carheight"], axis=1)
db
# Out:
#      symboling aspiration doornumber      carbody drivewheel  curbweight  \
# 0            3        std        two  convertible        rwd        2548
# 1            3        std        two  convertible        rwd        2548
# 2            1        std        two    hatchback        rwd        2823
# 3            2        std       four        sedan        fwd        2337
# 4            2        std       four        sedan        4wd        2824
# ..         ...        ...        ...          ...        ...         ...
# 200         -1        std       four        sedan        rwd        2952
# 201         -1      turbo       four        sedan        rwd        3049
# 202         -1        std       four        sedan        rwd        3012
# 203         -1      turbo       four        sedan        rwd        3217
# 204         -1      turbo       four        sedan        rwd        3062
#
#     enginetype cylindernumber  enginesize fuelsystem  boreratio  stroke  \
# ...

# %%
# Plotting Histogram
db.hist (bins = 10, figsize = (35,25))
plt.tight_layout()
plt.show()

# %%
# Encoding categorical datas
db = pd.get_dummies(db, drop_first=True)
db
# Out:
#      symboling  curbweight  enginesize  boreratio  stroke  compressionratio  \
# 0            3        2548         130       3.47    2.68               9.0
# 1            3        2548         130       3.47    2.68               9.0
# 2            1        2823         152       2.68    3.47               9.0
# 3            2        2337         109       3.19    3.40              10.0
# 4            2        2824         136       3.19    3.40               8.0
# ..         ...         ...         ...        ...     ...               ...
# 200         -1        2952         141       3.78    3.15               9.5
# 201         -1        3049         141       3.78    3.15               8.7
# 202         -1        3012         173       3.58    2.87               8.8
# 203         -1        3217         145       3.01    3.40              23.0
# 204         -1        3062         141       3.78    3.15               9.5
#
# ...

# %%
# Plotting HEATMAP
import seaborn as sns
plt.figure( figsize = (90, 76))
sns.heatmap(db.corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Importing Models

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score

# %%
x=db.drop(['price'], axis =1)
y=db.iloc[:,10].values

# Splitting the datasets into training and test sets
x_train, x_test, y_train, y_test =train_test_split(x,y, test_size=0.2, random_state=54)

print(x_train)
print(x_test)
print(y_train)
print(y_test)
# Out:
#      symboling  curbweight  enginesize  boreratio  stroke  compressionratio  \
# 55           3        2380          70       3.33   3.255               9.4
# 125          3        2778         151       3.94   3.110               9.5
# 116          0        3252         152       3.70   3.520              21.0
# 7            1        2954         136       3.19   3.400               8.5
# 150          1        1985          92       3.05   3.030               9.0
# ..         ...         ...         ...        ...     ...               ...
# 23           1        2128          98       3.03   3.390               7.6
# 15           0        3230         209       3.62   3.390               8.0
# 130          0        2579         132       3.46   3.900               8.7
# 69           0        3495         183       3.58   3.640              21.5
# 111          0        3075         120       3.46   2.190               8.4
#
# ...

# %%
# Train the model
rf = RandomForestRegressor(n_estimators = 15, random_state = 46)
rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=15, random_state=46)

# %%
# Predicting model
y_pred = rf.predict(x_test)
print(y_pred)
# Out:
# [19665.26666667 11378.06666667  7902.4        18875.86666667
#  13622.2        36685.36666667  9846.6         8558.4
#   8672.33333333  8116.          5794.86666667  9021.13333333
#  11517.13333333 13823.93333333  6852.46666667 16043.33333333
#  38524.46666667  8822.6         9562.06666667 18057.06666667
#  17346.26666667 13652.86666667 15750.81113333  9220.28888889
#   9220.28888889 16863.66666667  8314.16666667 15916.6
#  15456.26666667  8045.8         9872.86666667  6477.13333333
#  15434.06666667 11927.46666667 16101.13333333 15241.53333333
#  33062.7         6099.32666667  7741.4         7690.33333333
#   7947.32666667]

# %%
# Model accuacy
print("\n Random Forest regression mean squared error:", mean_squared_error(y_test, y_pred))

print("\n Random Forest Regression  mean absolute error:",mean_absolute_error(y_test, y_pred))

print("\n Random Forest Regression mean absolute percentage error :", mean_absolute_percentage_error(y_test,y_pred))
print("\n Random Forest r2 score:", r2_score(y_test, y_pred))
# Out:
#  Random Forest regression mean squared error: 6268842.781861403
#
#  Random Forest Regression  mean absolute error: 1693.3092146341464
#
#  Random Forest Regression mean absolute percentage error : 0.12460350253136261
#
#  Random Forest r2 score: 0.909181251674542
